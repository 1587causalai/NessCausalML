# %% [markdown]
# # 图网络 Researchers
#
# 本文介绍当前活跃的图网络研究图网络的一线工作者和主要工作。

# %% [markdown]
# ## 北京智源人工智能研究院
#
#
# - 清华大学有若干图网络的一线工作者，包括刘知远，唐杰 jietang@tsinghua.edu.cn 等等
# - 石川 (北邮，电商中的应用)
# - 沈伟华 中科院 shenhuawei@ict.ac.cn Convolutional Neural Networks
# - gjsong@pku.edu.cn 宋老师(62754785) 课件来啦！ 链接: https://pan.baidu.com/s/1Mj6i0I0jH5KF9MRpABwp1w 提取码: 45ns

# %% [markdown]
# ## 图网络和因果推理

# %% [markdown]
# 唐杰，图网络和认知推理 jietang@tsinghua.edu.cn, http://keg.cs.tsinghua.edu.cn/jietang/
#
# Tsinghua: Stable Learning: The Convergence of Machine Learning and Causal Inference, by Cui Peng(cuip@tsinghua.edu.cn) http://pengcui.thumedialab.com/
